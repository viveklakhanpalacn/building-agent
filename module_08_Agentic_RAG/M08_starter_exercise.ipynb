# %% [markdown]
# # [STARTER] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv,dotenv_values
load_dotenv(dotenv_path=".env") # I added the dotenv_path parameter as a reminder for myself that can pass something here if needed... ex. "../../../.env"
config = dotenv_values() # could have also used os.environ.get("UDACITY_OPENAI_API_KEY") I think, but I like the config approach better
api_key = config.get("UDACITY_OPENAI_API_KEY")
base_url = config.get("BASE_URL")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(openai_api_key=api_key, api_base=base_url)
db.create_store(store_name="game-store")

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM(
    model="gpt-4o-mini",
    temperature=0.3,
    api_key=api_key,
    base_url=base_url
)

# %%
# TODO: Add the games pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method
file_path="TheGamingIndustry2024.pdf"
games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(store_name="game-store", pdf_path=file_path)
)
# Out:
# VectorStore `game-store` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke(
    "What's the  state of virtual reality"
)
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by its significant impact on the gaming industry, allowing gamers to immerse themselves in expansive digital worlds. VR technology enhances gaming experiences by providing high-fidelity graphics, intuitive controls, and realistic audio, enabling players to interact in a way that feels lifelike. Games like "Half-Life: Alyx" exemplify this immersive experience, where players' decisions and actions have meaningful consequences in a richly crafted environment. Overall, VR is transforming gameplay and player engagement, contributing to the growth of the gaming market, which is projected to reach substantial revenues in the coming years.

# %%
# TODO: Add the electric vehicles pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method
db.create_store(store_name="global-outlook-store")
loader_service = CorpusLoaderService(db)
file_path="GlobalEVOutlook2025.pdf"
electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(store_name="global-outlook-store", pdf_path=file_path)
)
# Out:
# VectorStore `global-outlook-store` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil had nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
# TODO: Define a tool that returns result.get_final_state()["answer"]
# DONOT Forget about defining the tool docstrings
@tool
def search_global_ev_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: Global EV Outlook 2025
    Publisher: International Energy Agency
    Release: May 2025
    ```
        The Global EV Outlook is an annual publication that reports on recent
        developments in electric mobility around the world. It is developed with the support
        of members of the Electric Vehicles Initiative (EVI).
    ```

    args:
        query (str): Search query
    """    
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# TODO: Define a tool that returns result.get_final_state()["answer"]
# DONOT Forget about defining the tool docstrings
@tool
def search_games_market_report_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: The Gaming Industry in 2024 - Trends, Technologies & Predictions
    Publisher: Ixie Gaming
    Release: 2024
    ```
        The gaming industry, on the brink of transformative change due to technological
        advancements, is redefining entertainment and social interaction with
        immersive, personalized, and interactive experiences.
    ```

    args:
        query (str): Search query
    """
    result:Run = games_market_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
# TODO: Add the tools you have defined and the instructions to your agent
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],    
    instructions=(
        "You are an Agentic RAG assistant that can intelligently decide which tools to use "
        "to answer user questions. Reason about about the response, change the query and call the tool again if needed "
        "in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers."
    ),
    api_key=api_key,
    base_url=base_url
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_rsRh7AWAHHlPSQ2yG1sxLBal', function=Function(arguments='{"query":"2025 Oscar for International Movie winner"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_tYNeLcTschN64MW9sTFUjwIy', function=Function(arguments='{"query":"2025 Oscar for International Movie winner"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = It appears that I couldn't find the information regarding the winner of the 2025 Oscar for International Movie in the available sources.
#
# This could be due to the fact that the tools I have access to are focused on specific topics like electric vehicles and the gaming industry, rather than film awards. Unfortunately, I don't have access to real-time information or databases that contain the latest Oscar winners.
#
# For the most accurate and up-to-date information on the Oscars, I recommend checking official sources like the Academy Awards website or reputable news outlets. If you have any other questions or need information on a different topic, feel free to ask!, tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_HpCFDLiYeEioxGF50RGn4DbP', function=Function(arguments='{"query":"electric car exports Asia Pacific 2024 excluding China"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_yxeGvZETlwpzeXLaNj6FSFi0', function=Function(arguments='{"query":"electric vehicle exports 2024 Asia Pacific countries"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, the Asia Pacific region, particularly Southeast Asia, is expected to see significant growth in electric vehicle (EV) exports, driven by favorable policies and the establishment of manufacturing hubs. Countries like Thailand, Indonesia, the Philippines, Vietnam, and Singapore are implementing measures such as reduced import duties, tax exemptions, and subsidies to support EV adoption and local production. The outlook suggests that Southeast Asia could become a key manufacturing hub for EVs, with Chinese OEMs increasing their overseas manufacturing capacity in the region. By 2026, the manufacturing capacity of Chinese OEMs in Southeast Asia is projected to nearly triple, reaching around 1.2 million vehicles.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_N9wC9thzWBFrEQgwAz04cV7N', function=Function(arguments='{"query":"electric vehicle exports top countries 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, the top countries for electric vehicle exports included China, which remained the world's largest exporter with over 1.15 million electric cars exported. The United States was a significant destination for exports from the Asia Pacific region, which included Japan and Korea, accounting for more than a quarter of the 1 million electric cars produced in that region. Additionally, Mexico became the largest electric car trade partner for the United States, with net exports reaching 145,000 vehicles. The European Union also exported around 110,000 electric cars to the United States, ranking fourth in net electric car exports to that country.", tool_calls = None)
#  -> (role = assistant, content = Based on the information retrieved, it appears that the two countries in the Asia Pacific region (excluding China) that accounted for most of the electric car exports in 2024 are Japan and South Korea. These countries play a significant role in the electric vehicle market and are major contributors to the production and export of electric vehicles in the region.
#
# If you have more specific questions or need further details, feel free to ask!, tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "Why is generative AI seen more as an accelerator than a replacement in game development?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Why is generative AI seen more as an accelerator than a replacement in game development?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_yU8i3NUoLCtDqvl7c91SMg7N', function=Function(arguments='{"query":"generative AI accelerator replacement game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_Zng5wSBEorfGBs0z2ZmIiOR4', function=Function(arguments='{"query":"impact of generative AI in game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "The impact of generative AI in game development is significant as it enhances various aspects of the gaming experience. AI simulates intelligent behavior and automates complex tasks, which streamlines processes and improves functionality. It plays a crucial role in developing non-player characters (NPCs), creating dynamic and responsive gaming environments that enhance realism and depth in gameplay. For example, in games like \"The Last of Us,\" AI allows opponents and companions to react in real-time to player actions, marking it as a vital innovation in modern gaming. Overall, AI is reshaping the gaming industry, which is valued at $200 billion, by enabling more immersive and engaging experiences.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_8wGZW44Mjx8hT7nlPC2DeHwj', function=Function(arguments='{"query":"generative AI benefits game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "Generative AI benefits game development by enhancing the design and development processes, automating complex tasks, and simulating intelligent behavior. This technology allows for the creation of dynamic and responsive gaming environments, improving realism and adding depth to gameplay. For example, AI can assist in developing non-player characters (NPCs) that react in real-time to player actions, as seen in games like \"The Last of Us.\" Overall, AI is a significant innovation in the gaming industry, contributing to a more engaging and immersive gaming experience.", tool_calls = None)
#  -> (role = assistant, content = Generative AI is increasingly viewed as an accelerator rather than a replacement in game development for several reasons:
#
# 1. **Enhancing Creativity and Design**: Generative AI tools assist developers by automating complex tasks, allowing them to focus on creative aspects like storytelling, character development, and world-building. This collaborative approach fosters innovation rather than replacing human creativity.
#
# 2. **Dynamic Environments**: AI can create more immersive and responsive gaming environments. For instance, it can simulate intelligent behavior in non-player characters (NPCs), enabling them to react in real-time to player actions, which enhances the overall gameplay experience. This is evident in games like "The Last of Us," where AI-driven NPCs contribute significantly to the game's realism.
#
# 3. **Efficiency in Development**: By automating routine tasks—such as texture generation, level design, or even debugging—generative AI streamlines the development process. This efficiency allows developers to allocate more time to refining game mechanics and enhancing user experiences instead of getting bogged down with repetitive tasks.
#
# 4. **Improving Engagement**: Generative AI technology can lead to the development of more engaging and personalized gaming experiences. By using AI to analyze player behavior, developers can tailor experiences that keep players invested and engaged over longer periods.
#
# 5. **Industry Growth**: With the gaming industry valued at around $200 billion, the integration of generative AI is seen as a vital innovation that not only enhances current projects but also opens up new avenues for growth and exploration in interactive entertainment.
#
# In summary, generative AI acts as a powerful tool that amplifies the capabilities of game developers, rather than replacing them. It enhances creativity, improves efficiency, and leads to richer player experiences, marking its role as an accelerator in the evolution of game development., tool_calls = None)
